# %%
#this is to call the csv file from the folder
data = pd.read_csv(r"export (1).csv")

# %%
display(data)
# Out:
#             date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 0     2016-01-01   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN
# 1     2016-01-02  22.9  16.0  31.0   NaN   NaN    NaN   8.4   NaN     NaN
# 2     2016-01-03  22.8  14.0  32.0   NaN   NaN    NaN   7.8   NaN     NaN
# 3     2016-01-04   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN
# 4     2016-01-05   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN
# ...          ...   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 2920  2023-12-30  21.8  18.0  27.0   0.0   NaN  100.0  11.9   NaN  1018.3
# 2921  2023-12-31  20.9  16.8  26.0   0.0   NaN   98.0  14.1   NaN  1017.7
# 2922  2024-01-01  21.2  17.0  27.0   0.0   NaN   87.0   9.1   NaN  1017.8
# 2923  2024-01-02  21.6  18.0  26.0   0.0   NaN   96.0  11.9   NaN  1017.1
# 2924  2024-01-03  21.1  15.6  26.6   0.2   NaN  102.0  12.8   NaN  1014.5
#
#       tsun
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...

# %%
data.describe()
# Out:
#               tavg         tmin         tmax         prcp  snow         wdir  \
# count  2618.000000  2618.000000  2618.000000  1096.000000   0.0  1535.000000
# mean     23.778075    19.299885    29.125898     2.972628   NaN   194.768730
# std       2.457604     2.853999     3.002754     5.960736   NaN    89.335403
# min      17.800000     9.000000    19.000000     0.000000   NaN     0.000000
# 25%      22.200000    18.000000    27.000000     0.000000   NaN   100.000000
# 50%      23.500000    20.000000    29.000000     0.200000   NaN   250.000000
# 75%      25.200000    21.000000    31.000000     3.200000   NaN   267.000000
# max      34.200000    30.000000    40.000000    64.000000   NaN   356.000000
#
#               wspd  wpgt         pres  tsun
# count  2581.000000   0.0  1389.000000   0.0
# mean     12.606664   NaN  1014.238877   NaN
# std       5.313539   NaN     2.713593   NaN
# min       1.200000   NaN  1007.200000   NaN
# 25%       8.900000   NaN  1012.200000   NaN
# ...

# %%
# A new representation of the dataset according to your needs
dataf1 = pd.DataFrame(data, columns = ["date", "tavg" , "tmax", "tmin", "wspd", "prcp"])
dataf1
# Out:
#             date  tavg  tmax  tmin  wspd  prcp
# 0     2016-01-01   NaN   NaN   NaN   NaN   NaN
# 1     2016-01-02  22.9  31.0  16.0   8.4   NaN
# 2     2016-01-03  22.8  32.0  14.0   7.8   NaN
# 3     2016-01-04   NaN   NaN   NaN   NaN   NaN
# 4     2016-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...
# 2920  2023-12-30  21.8  27.0  18.0  11.9   0.0
# 2921  2023-12-31  20.9  26.0  16.8  14.1   0.0
# 2922  2024-01-01  21.2  27.0  17.0   9.1   0.0
# 2923  2024-01-02  21.6  26.0  18.0  11.9   0.0
# 2924  2024-01-03  21.1  26.6  15.6  12.8   0.2
#
# [2925 rows x 6 columns]

# %%
#importing seaborn to visualize the data over the days
import seaborn as sns
sns.set()

graph1 = sns.lineplot(x = "tmax", y = "tavg", data = dataf1)
graph1

#sorry for the absolutely unclarified graph
# Out:
# <Axes: xlabel='tmax', ylabel='tavg'>

# %%
graph2 = sns.lineplot(x = "date", y = "tavg", data = dataf1)
graph2
# Out:
# <Axes: xlabel='date', ylabel='tavg'>

# %%
graph3 = sns.lineplot(x = "tmax", y = "tmin", data = dataf1)
graph3
# Out:
# <Axes: xlabel='tmax', ylabel='tmin'>

# %%
graph4 = sns.lineplot(x = "wspd", y = "tavg", data = dataf1)
graph4
# Out:
# <Axes: xlabel='wspd', ylabel='tavg'>
